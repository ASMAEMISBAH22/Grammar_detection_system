# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
project_path = "/content/drive/MyDrive/GrammarCorrectionProject/"

# %%
# !pip install datasets pandas scikit-learn ftfy
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy) (0.2.14)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.10.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1

# %%
# Download and load the "multilingual-gec" dataset from Hugging Face
from datasets import load_dataset
import pandas as pd
dataset = load_dataset("juancavallotti/multilingual-gec")
# Show the first 20 examples from the training split
df = pd.DataFrame(dataset["train"])
df.head(20)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# dataset_infos.json: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/31.4M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/332k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/216318 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2186 [00:00<?, ? examples/s]
#    lang                                           sentence  \
# 0    fr  Il est très important de parler une langue étr...
# 1    fr  En 1933-1934, elle plaide auprès du président ...
# 2    en  Plants, obviously, cannot move after they have...
# 3    fr  La lune était observée par cette porte afin d’...
# 4    de  Bis Anfang der 1990er Jahre war in beiden Rich...
# 5    fr  Il finit sa saison 2017-2018 avec une moyenne ...
# 6    es                            Quería hablarte de eso.
# 7    de  In den 90er Jahren beschäftigt er sich hauptsä...
# 8    es                                    Nadie dice eso.
# 9    en                          I looked at the schedule.
# 10   fr  Le général fatimide envahit l'émirat, vainc un...
# 11   de             Ich verspreche, keine Mühe zu scheuen.
# 12   es  La última vez que se hizo un "encuentro PlaySt...
# 13   en           It's very hard to get rid of bad habits.
# 14   fr  Le chapiteau est d'un style dorique, cependant...
# 15   en                  Anyway, I think I've said enough.
# 16   fr  Ce n'est pas une bonne voiture mais c'est touj...
# 17   de                  Ich hätte gerne heiße Schokolade.
# 18   fr  Joseph-Cléophas Saindon fut le fondateur de la...
# 19   fr  Les propriétaires de la ferme Walserhof, la fa...
#
#                                              modified  \
# 0   fix grammar: Il est très importante de parler ...
# 1   fix grammar: En 1933-1934, elle plaide auprès ...
# 2   fix grammar: Plants, obviously, cannot moved a...
# 3   fix grammar: Les lune était observée par cette...
# 4   fix grammar: Bis Anfang der 1990er Jahre war i...
# 5   fix grammar: Il finissent sa saison 2017-2018 ...
# 6                 fix grammar: Quería ablarte de eso.
# 7   fix grammar: In ein 90er Jahren beschaftigt er...
# 8                        fix grammar: Nadie dise ezo.
# 9                  fix grammar: I looked at schedule.
# 10  fix grammar: Le fatimide général envahit l'émi...
# 11  fix grammar: Ich verspreche, keine Muhen zu sc...
# 12  fix grammar: La última vez que se izo un "encu...
# 13  fix grammar: It am very hard to get rid of bad...
# 14  fix grammar: Le chapiteau est d'un style doriq...
# 15       fix grammar: Anyway, think I've said enough.
# 16  fix grammar: Ce n'est pas une bonne voiture ma...
# 17     fix grammar: Ich hatte gerne heibe Schokolade.
# 18  fix grammar: Joseph-Cléophas Saindon fut la fo...
# 19  fix grammar: Le propriétaires du la ferme Wals...
#
#                         transformation                  sec_transformation  \
# 0       AdjectiveGenderChangeDestroyer                                None
# 1            GenderDeterminerDestroyer                                None
# 2               VerbAgreementDestroyer                                None
# 3            PluralDeterminerDestroyer                                None
# 4   DeRemoveSpecialCharactersDestroyer                                None
# 5                  FrVerbNumberChanger                                None
# 6                       MuteHDestroyer                                None
# 7           ArticleDefChangerDestroyer  DeRemoveSpecialCharactersDestroyer
# 8               SimilarSoundsDestroyer                                None
# 9                 DeterminersDestroyer                                None
# 10         AdjectiveMisplacerDestroyer                                None
# 11              DetNounNumberDestroyer  DeRemoveSpecialCharactersDestroyer
# 12                      MuteHDestroyer                                None
# 13   PrepositionVerbAgreementDestroyer                                None
# 14      AdjectiveGenderChangeDestroyer                                None
# 15           RandomWordRemoveOperation                                None
# 16         PluralSingularNounDestroyer                                None
# 17  DeRemoveSpecialCharactersDestroyer                                None
# 18           GenderDeterminerDestroyer                                None
# 19               ContractionsDestroyer           PluralDeterminerDestroyer
#
#     __index_level_0__
# 0               44864
# 1               54700
# 2               13392
# 3               53121
# 4               15034
# 5                5211
# 6               53588
# 7                4387
# 8                 174
# 9               13691
# 10              36043
# 11               2514
# 12              13670
# 13              34111
# 14              31321
# 15              21498
# 16               4715
# 17              16911
# 18              44414
# 19               7165

# %%
# Keep only English (en) and French (fr) sentences
df = df[df["lang"].isin(["en", "fr"])]

# Show how many rows are left after filtering
print("Number of sentences after filtering:", len(df))

# Display the first 20 rows to confirm
df.head(20)
# Out:
# Number of sentences after filtering: 117362
#    lang                                           sentence  \
# 0    fr  Il est très important de parler une langue étr...
# 1    fr  En 1933-1934, elle plaide auprès du président ...
# 2    en  Plants, obviously, cannot move after they have...
# 3    fr  La lune était observée par cette porte afin d’...
# 5    fr  Il finit sa saison 2017-2018 avec une moyenne ...
# 9    en                          I looked at the schedule.
# 10   fr  Le général fatimide envahit l'émirat, vainc un...
# 13   en           It's very hard to get rid of bad habits.
# 14   fr  Le chapiteau est d'un style dorique, cependant...
# 15   en                  Anyway, I think I've said enough.
# 16   fr  Ce n'est pas une bonne voiture mais c'est touj...
# 18   fr  Joseph-Cléophas Saindon fut le fondateur de la...
# 19   fr  Les propriétaires de la ferme Walserhof, la fa...
# 25   fr                      C'est un de mes points forts.
# 26   fr  Le château de Craonne appartenait également à ...
# 28   fr  Cela fait 35 ans que je viens ici tous les sam...
# 31   fr  On enrichit les langues en les fouillant. Il f...
# 33   en          Technologies allow you to do more things.
# 38   en  Tom's father is Canadian and his mother is Jap...
# 40   fr              Elle est volubile, un peu exubérante.
#
#                                              modified  \
# 0   fix grammar: Il est très importante de parler ...
# 1   fix grammar: En 1933-1934, elle plaide auprès ...
# 2   fix grammar: Plants, obviously, cannot moved a...
# 3   fix grammar: Les lune était observée par cette...
# 5   fix grammar: Il finissent sa saison 2017-2018 ...
# 9                  fix grammar: I looked at schedule.
# 10  fix grammar: Le fatimide général envahit l'émi...
# 13  fix grammar: It am very hard to get rid of bad...
# 14  fix grammar: Le chapiteau est d'un style doriq...
# 15       fix grammar: Anyway, think I've said enough.
# 16  fix grammar: Ce n'est pas une bonne voiture ma...
# 18  fix grammar: Joseph-Cléophas Saindon fut la fo...
# 19  fix grammar: Le propriétaires du la ferme Wals...
# 25         fix grammar: C'est un du mes forts points.
# 26  fix grammar: Le château du Craonne appartenait...
# 28  fix grammar: Cela fait 35 ans que je viens ici...
# 31  fix grammar: On enrichis les langues en les fo...
# 33  fix grammar: Technologies allow you to do most...
# 38  fix grammar: Toms's fathers is Canadian and hi...
# 40  fix grammar: Elle est volubile, une peu exubér...
#
#                        transformation         sec_transformation  \
# 0      AdjectiveGenderChangeDestroyer                       None
# 1           GenderDeterminerDestroyer                       None
# 2              VerbAgreementDestroyer                       None
# 3           PluralDeterminerDestroyer                       None
# 5                 FrVerbNumberChanger                       None
# 9                DeterminersDestroyer                       None
# 10        AdjectiveMisplacerDestroyer                       None
# 13  PrepositionVerbAgreementDestroyer                       None
# 14     AdjectiveGenderChangeDestroyer                       None
# 15          RandomWordRemoveOperation                       None
# 16        PluralSingularNounDestroyer                       None
# 18          GenderDeterminerDestroyer                       None
# 19              ContractionsDestroyer  PluralDeterminerDestroyer
# 25        AdjectiveMisplacerDestroyer      ContractionsDestroyer
# 26              ContractionsDestroyer                       None
# 28        PluralSingularNounDestroyer                       None
# 31        AdjectiveMisplacerDestroyer     PersonVerbDisagreement
# 33    ComparativeSuperlativeDestroyer                       None
# 38       SingularsAndPluralsDestroyer                       None
# 40          GenderDeterminerDestroyer                       None
#
#     __index_level_0__
# 0               44864
# 1               54700
# 2               13392
# 3               53121
# 5                5211
# 9               13691
# 10              36043
# 13              34111
# 14              31321
# 15              21498
# 16               4715
# 18              44414
# 19               7165
# 25                 97
# 26              33894
# 28              28467
# 31               9901
# 33              18701
# 38              22141
# 40              40426

# %%
# Rename the columns so they make more sense for training
df = df.rename(columns={
    "modified": "source",   # sentence with error
    "sentence": "target"    # correct sentence
})

# Keep only useful columns
df = df[["source", "target", "lang"]]

# Show the first rows to confirm
df.head()
# Out:
#                                               source  \
# 0  fix grammar: Il est très importante de parler ...
# 1  fix grammar: En 1933-1934, elle plaide auprès ...
# 2  fix grammar: Plants, obviously, cannot moved a...
# 3  fix grammar: Les lune était observée par cette...
# 5  fix grammar: Il finissent sa saison 2017-2018 ...
#
#                                               target lang
# 0  Il est très important de parler une langue étr...   fr
# 1  En 1933-1934, elle plaide auprès du président ...   fr
# 2  Plants, obviously, cannot move after they have...   en
# 3  La lune était observée par cette porte afin d’...   fr
# 5  Il finit sa saison 2017-2018 avec une moyenne ...   fr

# %%
# Remove rows that have empty values (NaN)
df = df.dropna()

# Remove duplicate rows
df = df.drop_duplicates()

print("Rows after cleaning:", len(df))
# Out:
# Rows after cleaning: 114561

# %%
import re, html, unicodedata
from ftfy import fix_text

# ------------------------------
# 1. Fix broken Unicode characters
# ------------------------------
# Sometimes sentences in the dataset have weird or broken characters due to encoding issues.
# `fix_text` from ftfy library automatically detects and fixes common Unicode problems,
# making characters display correctly.
df["source"] = df["source"].map(fix_text)
df["target"] = df["target"].map(fix_text)

# ------------------------------
# 2. Decode HTML entities
# ------------------------------
# Some sentences may have HTML codes like &amp; (for &) or &lt; (for <).
# `html.unescape` converts these HTML codes back to normal characters.
# Example: "Hello &amp; goodbye" → "Hello & goodbye"
df["source"] = df["source"].map(html.unescape)
df["target"] = df["target"].map(html.unescape)

# ------------------------------
# 3. Normalize Unicode characters to a standard form
# ------------------------------
# Unicode has multiple ways to represent the same character.
# `unicodedata.normalize("NFKC", x)` converts all characters to a consistent format,
# so the model sees "é" the same way every time.
df["source"] = df["source"].map(lambda x: unicodedata.normalize("NFKC", x))
df["target"] = df["target"].map(lambda x: unicodedata.normalize("NFKC", x))

# ------------------------------
# 4. Collapse multiple spaces and remove extra spaces at the ends
# ------------------------------
# Sometimes sentences have double or triple spaces, or spaces at the start/end.
# We replace any sequence of whitespace with a single space and strip the ends.
# Example: "Hello   world  " → "Hello world"
df["source"] = df["source"].map(lambda x: re.sub(r"\s+", " ", x).strip())
df["target"] = df["target"].map(lambda x: re.sub(r"\s+", " ", x).strip())

# ------------------------------
# 5. Remove spaces before punctuation marks
# ------------------------------
# Some sentences may have a space before punctuation, which is unnatural.
# We remove spaces before . , ! ? ; :
# Example: "Hello world !" → "Hello world!"
df["source"] = df["source"].map(lambda x: re.sub(r"\s+([.,!?;:])", r"\1", x))
df["target"] = df["target"].map(lambda x: re.sub(r"\s+([.,!?;:])", r"\1", x))

# %%
#Remove rows where source == target (no correction needed)
df = df[df["source"] != df["target"]]
df = df.reset_index(drop=True)

# %%
#Split dataset into train/valid/test
#80% train, 10% validation, 10% test
#Stratify by language to keep English/French balance

from sklearn.model_selection import train_test_split
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df["lang"])
valid_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42, stratify=temp_df["lang"])

# %%
import os

# Make sure the folder exists
os.makedirs(project_path + "data/processed", exist_ok=True)

# Save CSVs with full path
train_df[["source", "target"]].to_csv(project_path + "data/processed/train.csv", index=False, encoding="utf-8")
valid_df[["source", "target"]].to_csv(project_path + "data/processed/valid.csv", index=False, encoding="utf-8")
test_df[["source", "target"]].to_csv(project_path + "data/processed/test.csv", index=False, encoding="utf-8")

print("CSV files saved successfully!")
# Out:
# CSV files saved successfully!

# %%
print("Train:", len(train_df), "Valid:", len(valid_df), "Test:", len(test_df))
print(train_df.head())
print(valid_df.head())
print(test_df.head())
# Out:
# Train: 91648 Valid: 11456 Test: 11457
#                                                   source  \
# 95330           fix grammar: Mary isn't beautiful is she
# 23753  fix grammar: Katherine Megan McArthur (born Au...
# 32436  fix grammar: Une municipalité du paroisse fut ...
# 53147     fix grammar: L'temps passé n'reviendra jamais.
# 67896  fix grammar: Jadis, un petite hameau existait ...
#
#                                                   target lang
# 95330                      Mary isn't beautiful, is she?   en
# 23753  Katherine Megan McArthur (born August 30, 1971...   en
# 32436  Une municipalité de paroisse fut créée sous le...   fr
# 53147                Le temps passé ne reviendra jamais.   fr
# 67896  Jadis, un petit hameau existait autour de la g...   fr
#                                                    source  \
# 64951   fix grammar: The soil on the island were not w...
# 27265               fix grammar: Je sens souvent déprimé.
# 60482   fix grammar: Le SAC sest de nouveau affilié so...
# 39903         fix grammar: In 1988 a new law were passed.
# 104928  fix grammar: Nathan demande donc de le aide à ...
#
#                                                    target lang
# 64951   The soil on the island was not good, so someti...   en
# 27265                         Je me sens souvent déprimé.   fr
# 60482   Le SAC s'est de nouveau affilié sous le numéro...   fr
# 39903                       In 1988 a new law was passed.   en
# 104928  Nathan demande donc de l'aide à Jodie qui acce...   fr
#                                                   source  \
# 85987  fix grammar: Some common examples that used du...
# 1763   fix grammar: Banks wasn't to cleared the Shena...
# 99859  fix grammar: Durant le fête il est d'usage de ...
# 83804  fix grammar: Tu as fourni des conseils très ut...
# 72197  fix grammar: Le Royaume-Uni est le huitième pa...
#
#                                                   target lang
# 85987  Some common examples that use dual-phase engin...   en
# 1763   Banks was to clear the Shenandoah Valley of Co...   en
# 99859  Durant la fête il est d'usage de se rendre dan...   fr
# 83804           Tu m'as fourni des conseils très utiles.   fr
# 72197  Le Royaume-Uni est le huitième pays à octroyer...   fr
